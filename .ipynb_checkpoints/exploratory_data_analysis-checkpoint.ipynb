# %%
import pandas as pd
from constants import dataset_path, dataset_EDA_path
  
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set()

# %%
df = pd.read_csv(dataset_path)

# %% [markdown]
# ### Descriptive analysis

# %%
initial_count_row = df.shape[0]
initial_count_row
# Out:
# 11744

# %%
df.tail(2)
# Out:
#         repo language   author  \
# 11742  react       js  bvaughn
# 11743  react       js  bvaughn
#
#                                                    title body  \
# 11742  Add noop useDebugValue hook to partial/server ...  NaN
# 11743  useDebugValue should throw if used in a class ...  NaN
#
#                 created_at            closed_at     authors_in_comments  \
# 11742  2019-01-15 16:50:08  2019-01-15 19:00:04  ['gaearon', 'bvaughn']
# 11743  2019-01-15 21:19:24  2019-01-15 21:49:40                      []
#
#                         reviews          labels  \
# 11742              ['APPROVED']  ['CLA Signed']
# 11743  ['APPROVED', 'APPROVED']  ['CLA Signed']
#
#                     ...                \
# 11742               ...
# 11743               ...
#
#                                                  commits  \
# 11742  ['Add noop useDebugValue hook to partial/serve...
# 11743  ['useDebugValue should throw if used in a clas...
#
#                                            diff_file_url  changes title_count  \
# 11742  https://github.com/facebook/react/pull/14597.diff       16          54
# 11743  https://github.com/facebook/react/pull/14601.diff       20          55
#
#       body_count  labels_count  commits_count  latency  \
# 11742          0             1              1      130
# 11743          0             1              1       30
#
#        pull_requests_neighbours_latency  pull_requests_neighbours_count
# 11742                              1309                               7
# 11743                              1309                               7
#
# [2 rows x 23 columns]

# %%
df.describe()
# Out:
#            additions      deletions  changed_files        changes  \
# count   11744.000000   11744.000000   11744.000000   11744.000000
# mean      692.327401     483.606182      16.582595    1175.933583
# std      8812.626004    6481.933598     142.525719   14683.322896
# min         0.000000       0.000000       0.000000       0.000000
# 25%         2.000000       1.000000       1.000000       4.000000
# 50%        11.000000       3.000000       2.000000      19.000000
# 75%        57.000000      20.000000       4.000000      85.000000
# max    341495.000000  279337.000000    3000.000000  557340.000000
#
#         title_count    body_count  labels_count  commits_count       latency  \
# count  11744.000000  11744.000000  11744.000000   11744.000000  11744.000000
# mean      41.431029    612.420385      1.268903       2.677452    507.640072
# std       16.028566   2843.160253      0.942655       5.582910    471.627438
# min        3.000000      0.000000      0.000000       0.000000      0.000000
# 25%       30.000000     73.000000      1.000000       1.000000     69.000000
# 50%       41.000000    223.000000      1.000000       1.000000    343.000000
# 75%       51.000000    536.000000      2.000000       2.000000    931.000000
# max      146.000000  64124.000000      8.000000      50.000000   1440.000000
#
#        pull_requests_neighbours_latency  pull_requests_neighbours_count
# count                      11744.000000                    11744.000000
# mean                        9294.655399                       22.118869
# std                         6333.401389                       15.582526
# min                            0.000000                        0.000000
# 25%                         4701.000000                       10.000000
# 50%                         8394.500000                       20.000000
# 75%                        12654.250000                       31.000000
# max                        47312.000000                      132.000000

# %% [markdown]
# ### Remove outliers
#
# These constrain aim for filtering those PRs which have been merged in an active repository and present a nonextreme diff changes

# %%
max_latency = 7 * 24 * 60 #7 days
min_latency = 1 #1 minute
max_changes = 2000
min_changes = 1
max_changed_files = 50
min_changed_files = 1
min_pull_requests_neighbours_count = 5

# %% [markdown]
# #### Set min and max allowed `latency`

# %%
df.latency.hist()
np.logical_and(df.latency >= min_latency, df.latency <= max_latency).sum() / df.shape[0]
# Out:
# 0.9964237057220708

# %%
df = df[np.logical_and(df.latency >= min_latency, df.latency <= max_latency)]
df.latency.hist();

# %% [markdown]
# #### Set min and max allowed `changes`

# %%
df.changes.hist()
np.logical_and(df.changes >= min_changes, df.changes <= max_changes).sum() / df.shape[0]
# Out:
# 0.9582122714065971

# %%
df = df[np.logical_and(df.changes >= min_changes, df.changes <= max_changes)]
df.changes.hist();

# %% [markdown]
# #### Set min and max allowed `changed_files`

# %%
df.changed_files.hist()
np.logical_and(df.changed_files >= min_changed_files, df.changed_files <= max_changed_files).sum() / df.shape[0]
# Out:
# 0.9912601444751628

# %%
df = df[np.logical_and(df.changed_files >= min_changed_files, df.changed_files <= max_changed_files)]
df.changed_files.hist();

# %% [markdown]
# #### Set min allowed `pull_requests_neighbours_count`

# %%
df.pull_requests_neighbours_count.hist()
(df.pull_requests_neighbours_count >= min_pull_requests_neighbours_count).sum() / df.shape[0]
# Out:
# 0.9280251911830859

# %%
df = df[df.pull_requests_neighbours_count >= min_pull_requests_neighbours_count]
df.pull_requests_neighbours_count.hist();

# %%
df.shape[0] / initial_count_row
# Out:
# 0.8783208446866485

# %%
df.describe()
# Out:
#           additions     deletions  changed_files       changes   title_count  \
# count  10315.000000  10315.000000   10315.000000  10315.000000  10315.000000
# mean      61.074939     32.958216       3.685894     94.033156     41.963451
# std      152.354485    107.010937       5.394791    222.178779     15.969433
# min        0.000000      0.000000       1.000000      1.000000      4.000000
# 25%        2.000000      1.000000       1.000000      4.000000     31.000000
# 50%       10.000000      3.000000       2.000000     18.000000     41.000000
# 75%       50.000000     17.000000       4.000000     75.000000     51.000000
# max     1953.000000   1769.000000      49.000000   1996.000000    146.000000
#
#          body_count  labels_count  commits_count       latency  \
# count  10315.000000  10315.000000   10315.000000  10315.000000
# mean     425.313912      1.233446       2.196219    499.698206
# std     1371.715284      0.875067       3.285002    469.321735
# min        0.000000      0.000000       0.000000      1.000000
# 25%       73.000000      1.000000       1.000000     66.000000
# 50%      217.000000      1.000000       1.000000    331.000000
# 75%      519.000000      2.000000       2.000000    917.000000
# max    64124.000000      8.000000      50.000000   1440.000000
#
#        pull_requests_neighbours_latency  pull_requests_neighbours_count
# count                      10315.000000                    10315.000000
# mean                        9974.096171                       23.852545
# std                         6128.928393                       15.045309
# min                          110.000000                        5.000000
# 25%                         5624.500000                       12.000000
# 50%                         8975.000000                       21.000000
# 75%                        13175.000000                       32.000000
# max                        47312.000000                      132.000000

# %% [markdown]
# ### Synthesize variables

# %%
df['changes_commit_ratio'] = df.commits_count / df.changes
df['add_delete_diff'] = df.additions - df.deletions
df.head(2)
# Out:
#         repo language     author  \
# 6  bootstrap       js     weslly
# 7  bootstrap       js  pthrasher
#
#                                                title  \
# 6  fixed background-color for disabled links in p...
# 7                    Fix for popover issue from #136
#
#                                                 body           created_at  \
# 6  'none' isn't a valid value for background-colo...  2011-08-26 16:31:56
# 7  This is a fix for the popover issue in fluid l...  2011-09-02 15:13:10
#
#              closed_at                              authors_in_comments  \
# 6  2011-08-26 16:53:23                                          ['mdo']
# 7  2011-09-02 16:51:32  ['mdo', 'pthrasher', 'mdo', 'pthrasher', 'mdo']
#
#   reviews labels       ...         changes  title_count  body_count  \
# 6      []     []       ...               2           55         121
# 7      []     []       ...              14           31         289
#
#   labels_count commits_count  latency  pull_requests_neighbours_latency  \
# 6            0             1       21                               753
# 7            0             4       98                               774
#
#    pull_requests_neighbours_count  changes_commit_ratio  add_delete_diff
# 6                               6              0.500000                0
# 7                               7              0.285714                0
#
# [2 rows x 25 columns]

# %% [markdown]
# ### Comparative analysis

# %%
corr = df.corr()
fig, ax = plt.subplots(figsize=(15,15)) 
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, linewidths=.5, ax=ax)

# %%
plt.scatter(x = df.latency, y = df.changes, alpha=0.1)
plt.show()

# %%
df.to_csv()
