# %%
import pandas as pd
from constants import dataset_path
# %matplotlib inline  
import seaborn as sns
sns.set()

# %%
df = pd.read_csv(dataset_path)

# %%
df.shape
# Out:
# (11333, 22)

# %%
df.tail(2)
# Out:
#         repo language   author  \
# 11331  react       js  bvaughn
# 11332  react       js  bvaughn
#
#                                                    title body  \
# 11331  Add noop useDebugValue hook to partial/server ...  NaN
# 11332  useDebugValue should throw if used in a class ...  NaN
#
#                 created_at            closed_at     authors_in_comments  \
# 11331  2019-01-15 16:50:08  2019-01-15 19:00:04  ['gaearon', 'bvaughn']
# 11332  2019-01-15 21:19:24  2019-01-15 21:49:40                      []
#
#                         reviews          labels  \
# 11331              ['APPROVED']  ['CLA Signed']
# 11332  ['APPROVED', 'APPROVED']  ['CLA Signed']
#
#                     ...                changed_files  \
# 11331               ...                            2
# 11332               ...                            2
#
#                                                  commits  \
# 11331  ['Add noop useDebugValue hook to partial/serve...
# ...

# %%
df.describe()
# Out:
#            additions      deletions  changed_files   title_count  \
# count   11333.000000   11333.000000   11333.000000  11333.000000
# mean      646.326215     465.484779      16.003177     41.502691
# std      8291.635919    6363.613333     137.754640     16.031603
# min         0.000000       0.000000       0.000000      4.000000
# 25%         2.000000       1.000000       1.000000     30.000000
# 50%        11.000000       3.000000       2.000000     41.000000
# 75%        58.000000      20.000000       4.000000     51.000000
# max    341495.000000  279337.000000    3000.000000    146.000000
#
#          body_count  labels_count  commits_count       latency  \
# count  11333.000000  11333.000000   11333.000000  11333.000000
# mean     603.187064      1.270273       2.670431    506.817171
# std     2773.376253      0.930290       5.498324    471.634245
# min        0.000000      0.000000       0.000000      0.000000
# ...

# %%
sns.distplot(df.additions)
